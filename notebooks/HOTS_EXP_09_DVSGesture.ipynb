# %%
# %cd '../HOTS'
from Tools import runjit, netparam, histoscore, histoscore_lagorce
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/antoine/homhots/HOTS/HOTS

# %%
sigma = None
pooling = False
homeinv = False
jitonic = [None,None] #[temporal, spatial]
jitter = False
R = 2
nbclust = [4,8,16]
filt = 2

timestr = '2021-03-29'
record_path = '../Records/EXP_06_DVSGESTURE/'
dataset = 'gesture'
nb_test = 264
nb_train = 1077
ds = 10

nb_test = nb_test//ds
nb_train = nb_train//ds
print(f'training set size: {nb_train} - testing set: {nb_test}')
# Out:
# training set size: 107 - testing set: 26

# %%
verbose=True
JS_score = []
JS_scorehom = []
JS_score_histav = []
JS_scorehom_histav = []
BA_score = []
BA_scorehom = []
BA_score_histav = []
BA_scorehom_histav = []
kNN6_score = []
kNN6_scorehom = []
kNN3_score = []
kNN3_scorehom = []

R = 2
tauz = [0.1, 1, 2, 5, 10, 20, 30, 40, 50, 60]

for name in ['homhots']:
    for tau in tauz:
        hotshom, homeotest = netparam(name, filt, tau, nbclust, sigma, homeinv, jitter, timestr, dataset, R, nb_learn=50, verbose = verbose)
        hotshom.plotlayer()
        trainhistomap = hotshom.running(homeotest=homeotest, nb_digit = nb_train, outstyle='histo', dataset=dataset, verbose=verbose)
        testhistomap = hotshom.running(homeotest = homeotest, train=False, nb_digit=nb_test, jitonic=jitonic, dataset=dataset, verbose=verbose)
        
        score = histoscore(trainhistomap,testhistomap, verbose = verbose)
        if name=='hots':
            BA_score.append(score[0])
            JS_score.append(score[4])
            kNN3_score.append(score[5])
            kNN6_score.append(score[6])
        else:
            BA_scorehom.append(score[0])
            JS_scorehom.append(score[4])
            kNN3_scorehom.append(score[5])
            kNN6_scorehom.append(score[6])
        trainhistomap = hotshom.running(homeotest=homeotest, nb_digit = nb_train, outstyle='histav', dataset=dataset, verbose=verbose)
        score = histoscore_lagorce(trainhistomap,testhistomap, verbose = verbose)
        if name=='hots':
            BA_score_histav.append(score[0])
            JS_score_histav.append(score[4])
        else:
            BA_scorehom_histav.append(score[0])
            JS_scorehom_histav.append(score[4])
# Out:
# The dataset used is: gesture
# ../Records/EXP_06_DVSGESTURE/models/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[0.1, 1.0, 10.0]_[2, 4, 8]_False.pkl
#   1%|          | 1/110 [00:42<1:16:41, 42.21s/it]
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[0.1, 1.0, 10.0]_[2, 4, 8]_False_107_[None, None]_histo.pkl
# ../Records/EXP_06_DVSGESTURE/test/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[0.1, 1.0, 10.0]_[2, 4, 8]_False_26_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 8.0% - eucli = 8.0% - norm = 8.0%
# Classification scores with entropy: Kullback-Leibler = 8.0% - Jensen-Shannon = 8.0%
# Classification scores with k-NN: 3-NN = 12.0% - 6-NN = 4.0%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[0.1, 1.0, 10.0]_[2, 4, 8]_False_107_[None, None]_histav.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 15.0% - eucli = 15.0% - norm = 15.0%
# Classification scores with entropy: Kullback-Leibler = 12.0% - Jensen-Shannon = 15.0%
# ----------------------------------------------------------------------------------------------------
# The dataset used is: gesture
# ../Records/EXP_06_DVSGESTURE/models/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[1.0, 10.0, 100.0]_[2, 4, 8]_False.pkl
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[1.0, 10.0, 100.0]_[2, 4, 8]_False_107_[None, None]_histo.pkl
# ../Records/EXP_06_DVSGESTURE/test/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[1.0, 10.0, 100.0]_[2, 4, 8]_False_26_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 19.0% - eucli = 23.0% - norm = 23.0%
# Classification scores with entropy: Kullback-Leibler = 15.0% - Jensen-Shannon = 19.0%
# Classification scores with k-NN: 3-NN = 31.0% - 6-NN = 31.0%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[1.0, 10.0, 100.0]_[2, 4, 8]_False_107_[None, None]_histav.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 19.0% - eucli = 15.0% - norm = 12.0%
# Classification scores with entropy: Kullback-Leibler = 23.0% - Jensen-Shannon = 19.0%
# ----------------------------------------------------------------------------------------------------
# The dataset used is: gesture
# ../Records/EXP_06_DVSGESTURE/models/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[2.0, 20.0, 200.0]_[2, 4, 8]_False.pkl
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[2.0, 20.0, 200.0]_[2, 4, 8]_False_107_[None, None]_histo.pkl
# ../Records/EXP_06_DVSGESTURE/test/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[2.0, 20.0, 200.0]_[2, 4, 8]_False_26_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 50.0% - eucli = 31.0% - norm = 31.0%
# Classification scores with entropy: Kullback-Leibler = 50.0% - Jensen-Shannon = 46.0%
# Classification scores with k-NN: 3-NN = 35.0% - 6-NN = 31.0%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[2.0, 20.0, 200.0]_[2, 4, 8]_False_107_[None, None]_histav.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 15.0% - eucli = 12.0% - norm = 8.0%
# Classification scores with entropy: Kullback-Leibler = 12.0% - Jensen-Shannon = 15.0%
# ----------------------------------------------------------------------------------------------------
# The dataset used is: gesture
# ../Records/EXP_06_DVSGESTURE/models/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[5.0, 50.0, 500.0]_[2, 4, 8]_False.pkl
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[5.0, 50.0, 500.0]_[2, 4, 8]_False_107_[None, None]_histo.pkl
# ../Records/EXP_06_DVSGESTURE/test/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[5.0, 50.0, 500.0]_[2, 4, 8]_False_26_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 38.0% - eucli = 38.0% - norm = 46.0%
# Classification scores with entropy: Kullback-Leibler = 38.0% - Jensen-Shannon = 38.0%
# Classification scores with k-NN: 3-NN = 38.0% - 6-NN = 42.0%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[5.0, 50.0, 500.0]_[2, 4, 8]_False_107_[None, None]_histav.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 23.0% - eucli = 23.0% - norm = 31.0%
# Classification scores with entropy: Kullback-Leibler = 19.0% - Jensen-Shannon = 23.0%
# ----------------------------------------------------------------------------------------------------
# The dataset used is: gesture
# ../Records/EXP_06_DVSGESTURE/models/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[10.0, 100.0, 1000.0]_[2, 4, 8]_False.pkl
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[10.0, 100.0, 1000.0]_[2, 4, 8]_False_107_[None, None]_histo.pkl
# ../Records/EXP_06_DVSGESTURE/test/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[10.0, 100.0, 1000.0]_[2, 4, 8]_False_26_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 54.0% - eucli = 46.0% - norm = 38.0%
# Classification scores with entropy: Kullback-Leibler = 46.0% - Jensen-Shannon = 54.0%
# Classification scores with k-NN: 3-NN = 38.0% - 6-NN = 46.0%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[10.0, 100.0, 1000.0]_[2, 4, 8]_False_107_[None, None]_histav.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 38.0% - eucli = 46.0% - norm = 38.0%
# Classification scores with entropy: Kullback-Leibler = 42.0% - Jensen-Shannon = 38.0%
# ----------------------------------------------------------------------------------------------------
# The dataset used is: gesture
# ../Records/EXP_06_DVSGESTURE/models/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[20.0, 200.0, 2000.0]_[2, 4, 8]_False.pkl
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[20.0, 200.0, 2000.0]_[2, 4, 8]_False_107_[None, None]_histo.pkl
# ../Records/EXP_06_DVSGESTURE/test/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[20.0, 200.0, 2000.0]_[2, 4, 8]_False_26_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 69.0% - eucli = 54.0% - norm = 50.0%
# Classification scores with entropy: Kullback-Leibler = 69.0% - Jensen-Shannon = 69.0%
# Classification scores with k-NN: 3-NN = 50.0% - 6-NN = 38.0%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[20.0, 200.0, 2000.0]_[2, 4, 8]_False_107_[None, None]_histav.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 31.0% - eucli = 27.0% - norm = 31.0%
# Classification scores with entropy: Kullback-Leibler = 27.0% - Jensen-Shannon = 31.0%
# ----------------------------------------------------------------------------------------------------
# The dataset used is: gesture
# ../Records/EXP_06_DVSGESTURE/models/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[30.0, 300.0, 3000.0]_[2, 4, 8]_False.pkl
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[30.0, 300.0, 3000.0]_[2, 4, 8]_False_107_[None, None]_histo.pkl
# ../Records/EXP_06_DVSGESTURE/test/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[30.0, 300.0, 3000.0]_[2, 4, 8]_False_26_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 42.0% - eucli = 42.0% - norm = 42.0%
# Classification scores with entropy: Kullback-Leibler = 46.0% - Jensen-Shannon = 42.0%
# Classification scores with k-NN: 3-NN = 27.0% - 6-NN = 27.0%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[30.0, 300.0, 3000.0]_[2, 4, 8]_False_107_[None, None]_histav.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 35.0% - eucli = 38.0% - norm = 35.0%
# Classification scores with entropy: Kullback-Leibler = 31.0% - Jensen-Shannon = 27.0%
# ----------------------------------------------------------------------------------------------------
# The dataset used is: gesture
# ../Records/EXP_06_DVSGESTURE/models/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[40.0, 400.0, 4000.0]_[2, 4, 8]_False.pkl
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[40.0, 400.0, 4000.0]_[2, 4, 8]_False_107_[None, None]_histo.pkl
# ../Records/EXP_06_DVSGESTURE/test/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[40.0, 400.0, 4000.0]_[2, 4, 8]_False_26_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 50.0% - eucli = 42.0% - norm = 42.0%
# Classification scores with entropy: Kullback-Leibler = 50.0% - Jensen-Shannon = 50.0%
# Classification scores with k-NN: 3-NN = 38.0% - 6-NN = 46.0%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[40.0, 400.0, 4000.0]_[2, 4, 8]_False_107_[None, None]_histav.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 35.0% - eucli = 19.0% - norm = 12.0%
# Classification scores with entropy: Kullback-Leibler = 35.0% - Jensen-Shannon = 35.0%
# ----------------------------------------------------------------------------------------------------
# The dataset used is: gesture
# ../Records/EXP_06_DVSGESTURE/models/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[50.0, 500.0, 5000.0]_[2, 4, 8]_False.pkl
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[50.0, 500.0, 5000.0]_[2, 4, 8]_False_107_[None, None]_histo.pkl
# ../Records/EXP_06_DVSGESTURE/test/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[50.0, 500.0, 5000.0]_[2, 4, 8]_False_26_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 46.0% - eucli = 31.0% - norm = 31.0%
# Classification scores with entropy: Kullback-Leibler = 46.0% - Jensen-Shannon = 54.0%
# Classification scores with k-NN: 3-NN = 27.0% - 6-NN = 23.0%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[50.0, 500.0, 5000.0]_[2, 4, 8]_False_107_[None, None]_histav.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 15.0% - eucli = 23.0% - norm = 19.0%
# Classification scores with entropy: Kullback-Leibler = 15.0% - Jensen-Shannon = 15.0%
# ----------------------------------------------------------------------------------------------------
# The dataset used is: gesture
# ../Records/EXP_06_DVSGESTURE/models/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[60.0, 600.0, 6000.0]_[2, 4, 8]_False.pkl
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[60.0, 600.0, 6000.0]_[2, 4, 8]_False_107_[None, None]_histo.pkl
# ../Records/EXP_06_DVSGESTURE/test/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[60.0, 600.0, 6000.0]_[2, 4, 8]_False_26_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 54.0% - eucli = 31.0% - norm = 31.0%
# Classification scores with entropy: Kullback-Leibler = 50.0% - Jensen-Shannon = 54.0%
# Classification scores with k-NN: 3-NN = 42.0% - 6-NN = 38.0%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[60.0, 600.0, 6000.0]_[2, 4, 8]_False_107_[None, None]_histav.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 27.0% - eucli = 15.0% - norm = 15.0%
# Classification scores with entropy: Kullback-Leibler = 23.0% - Jensen-Shannon = 27.0%
# ----------------------------------------------------------------------------------------------------

# %%
for i in range(len(tauz)):
    #j = np.log(tauz[i])
    j = tauz[i]
    #plt.plot(j,BA_score_histav[i], 'r +')
    #plt.plot(j,JS_score_histav[i], 'r o')
    plt.plot(j,BA_scorehom_histav[i], 'g +')
    plt.plot(j,JS_scorehom_histav[i], 'g o')
    plt.title('Performances with averaged histogram per classe')

# %%
for i in range(len(tauz)):
    j = np.log(tauz[i])
    j = tauz[i]
    #plt.plot(j,BA_score[i], 'r +')
    #plt.plot(j,JS_score[i], 'r o')
    #plt.plot(j,kNN3_score[i], 'r ^')
    #plt.plot(j,kNN6_score[i], 'r .')
    plt.plot(j,BA_scorehom[i], 'g +')
    plt.plot(j,JS_scorehom[i], 'g o')
    plt.plot(j,kNN3_scorehom[i], 'g ^')
    plt.plot(j,kNN6_scorehom[i], 'g .')
    plt.title('Performances with histogram per record')

# %%
verbose=False
JS_score = []
JS_scorehom = []
JS_score_histav = []
JS_scorehom_histav = []
BA_score = []
BA_scorehom = []
BA_score_histav = []
BA_scorehom_histav = []
kNN6_score = []
kNN6_scorehom = []
kNN3_score = []
kNN3_scorehom = []

Rz = [1, 2, 5, 10]
tau = 20

for name in ['homhots']:
    for R in Rz:
        hotshom, homeotest = netparam(name, filt, tau, nbclust, sigma, homeinv, jitter, timestr, dataset, R, nb_learn=50, verbose = verbose)
        #hotshom.plotlayer()
        trainhistomap = hotshom.running(homeotest=homeotest, nb_digit = nb_train, outstyle='histo', dataset=dataset, verbose=verbose)
        testhistomap = hotshom.running(homeotest = homeotest, train=False, nb_digit=nb_test, jitonic=jitonic, dataset=dataset, verbose=verbose)
        
        score = histoscore(trainhistomap,testhistomap, verbose = verbose)
        if name=='hots':
            BA_score.append(score[0])
            JS_score.append(score[4])
            kNN3_score.append(score[5])
            kNN6_score.append(score[6])
        else:
            BA_scorehom.append(score[0])
            JS_scorehom.append(score[4])
            kNN3_scorehom.append(score[5])
            kNN6_scorehom.append(score[6])
        trainhistomap = hotshom.running(homeotest=homeotest, nb_digit = nb_train, outstyle='histav', dataset=dataset, verbose=verbose)
        score = histoscore_lagorce(trainhistomap,testhistomap, verbose = verbose)
        if name=='hots':
            BA_score_histav.append(score[0])
            JS_score_histav.append(score[4])
        else:
            BA_scorehom_histav.append(score[0])
            JS_scorehom_histav.append(score[4])

# %%
for i in range(len(Rz)):
    j = Rz[i]
    #plt.plot(j,BA_score_histav[i], 'r +')
    #plt.plot(j,JS_score_histav[i], 'r o')
    plt.plot(j,BA_scorehom_histav[i], 'g +')
    plt.plot(j,JS_scorehom_histav[i], 'g o')
    plt.title('Performances with averaged histogram per classe')

# %%
for i in range(len(Rz)):
    j = Rz[i]
    #plt.plot(j,BA_score[i], 'r +')
    #plt.plot(j,JS_score[i], 'r o')
    #plt.plot(j,kNN3_score[i], 'r ^')
    #plt.plot(j,kNN6_score[i], 'r .')
    plt.plot(j,BA_scorehom[i], 'g +')
    plt.plot(j,JS_scorehom[i], 'g o')
    plt.plot(j,kNN3_scorehom[i], 'g ^')
    plt.plot(j,kNN6_scorehom[i], 'g .')
    plt.title('Performances with histogram per record')

# %% [markdown]
# # We choose tau = 10 ms and R = 2

# %%
verbose = True
tau = 10
R = 2
for name in ['homhots', 'hots']:
    hotshom, homeotest = netparam(name, filt, tau, nbclust, sigma, homeinv, jitter, timestr, dataset, R)#, nb_learn=50)
    hotshom.plotlayer()
    trainhistomap = hotshom.running(homeotest=homeotest, nb_digit = nb_train, outstyle='histo', dataset=dataset)
    testhistomap = hotshom.running(homeotest = homeotest, train=False, nb_digit=nb_test, jitonic=jitonic, dataset=dataset)
    score = histoscore(trainhistomap,testhistomap, verbose = verbose)
    trainhistomap = hotshom.running(homeotest=homeotest, nb_digit = nb_train, outstyle='histav', dataset=dataset)
    score = histoscore_lagorce(trainhistomap,testhistomap, verbose = verbose)
# Out:
#   1%|          | 1/110 [03:55<7:08:26, 235.84s/it]
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[10.0, 100.0, 1000.0]_[2, 4, 8]_False_107_[None, None]_histo.pkl
# ../Records/EXP_06_DVSGESTURE/test/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[10.0, 100.0, 1000.0]_[2, 4, 8]_False_26_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 54.0% - eucli = 46.0% - norm = 38.0%
# Classification scores with entropy: Kullback-Leibler = 46.0% - Jensen-Shannon = 54.0%
# Classification scores with k-NN: 3-NN = 38.0% - 6-NN = 46.0%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_06_DVSGESTURE/train/2021-03-29_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[10.0, 100.0, 1000.0]_[2, 4, 8]_False_107_[None, None]_histav.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 38.0% - eucli = 46.0% - norm = 38.0%
# Classification scores with entropy: Kullback-Leibler = 42.0% - Jensen-Shannon = 38.0%
# ----------------------------------------------------------------------------------------------------
# no jitter
# sensor formatting...
#   0%|          | 0/110 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-b45ffce9b541> in <module>
#       3 R = 2
#       4 for name in ['homhots', 'hots']:
# ----> 5     hotshom, homeotest = netparam(name, filt, tau, nbclust, sigma, homeinv, jitter, timestr, dataset, R)#, nb_learn=50)
#       6     hotshom.plotlayer()
#       7     trainhistomap = hotshom.running(homeotest=homeotest, nb_digit = nb_train, outstyle='histo', dataset=dataset)
#
# ~/homhots/HOTS/HOTS/Tools.py in netparam(name, filt, tau, nbclust, sigma, homeinv, jitter, timestr, dataset, R, nb_learn, maxevts, subset_size, kfold, kfold_ind, verbose)
#     216         krnlinit = 'first'
#     217         hotshom = network(krnlinit=krnlinit, filt=filt, tau=tau, R=R, nbclust=nbclust, homeo=homeo, sigma=sigma, homeinv=homeinv, jitter=jitter, timestr=timestr)
# --> 218         hotshom = hotshom.learning1by1(dataset=dataset, nb_digit = nb_learn, maxevts = maxevts, subset_size = subset_size, kfold = None, kfold_ind = None, verbose=verbose)
#     219     elif name=='homhots':
#     220         homeo = True
#
# ~/homhots/HOTS/HOTS/Network.py in learning1by1(self, nb_digit, dataset, diginit, filtering, jitonic, maxevts, subset_size, kfold, kfold_ind, verbose)
#     227                             if activ2 and np.sum(timesurf)>0:
#     228                             #if activ==True:
# --> 229                                 p, dist = self.L[lay].run(timesurf, learn)
#     230                                 if learn:
#     231                                     self.stats[lay].update(p, self.L[lay].kernel, timesurf, dist)
#
# ~/homhots/HOTS/HOTS/Layer.py in run(self, TS, learn)
#      76         else:
#      77             p = np.zeros([len(h),1])
# ---> 78             p[np.argmax(h)] = 1
#      79
#      80         if plotdic==True:
#
# <__array_function__ internals> in argmax(*args, **kwargs)
#
# /usr/lib/python3/dist-packages/numpy/core/fromnumeric.py in argmax(a, axis, out)
#    1151
#    1152     """
# -> 1153     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#    1154
#    1155
#
# /usr/lib/python3/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      59
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#      63         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %%
verbose=False
JS_score = []
JS_scorehom = []
JS_score_histav = []
JS_scorehom_histav = []
BA_score = []
BA_scorehom = []
BA_score_histav = []
BA_scorehom_histav = []
kNN6_score = []
kNN6_scorehom = []
kNN3_score = []
kNN3_scorehom = []

tau = 0.07

for name in ['hots', 'homhots']:
    for i in range(20):
        timestr = '2021-03-28'+str(i)
        hotshom, homeotest = netparam(name, filt, tau, nbclust, sigma, homeinv, jitter, timestr, dataset, R, verbose=verbose)#, nb_learn=50)
        trainhistomap = hotshom.running(homeotest=homeotest, nb_digit = nb_train, outstyle='histo', dataset=dataset, verbose=verbose)
        testhistomap = hotshom.running(homeotest = homeotest, train=False, nb_digit=nb_test, jitonic=jitonic, dataset=dataset, verbose=verbose)
        score = histoscore(trainhistomap,testhistomap, verbose = verbose)
        if name=='hots':
            BA_score.append(score[0])
            JS_score.append(score[4])
            kNN3_score.append(score[5])
            kNN6_score.append(score[6])
        else:
            BA_scorehom.append(score[0])
            JS_scorehom.append(score[4])
            kNN3_scorehom.append(score[5])
            kNN6_scorehom.append(score[6])
        trainhistomap = hotshom.running(homeotest=homeotest, nb_digit = nb_train, outstyle='histav', dataset=dataset, verbose=verbose)
        score = histoscore_lagorce(trainhistomap,testhistomap, verbose = verbose)
        if name=='hots':
            BA_score_histav.append(score[0])
            JS_score_histav.append(score[4])
        else:
            BA_scorehom_histav.append(score[0])
            JS_scorehom_histav.append(score[4])

# %%
labels = ['original HOTS', 'Homeostasis']
JS_means = [np.mean(JS_score_histav), np.mean(JS_scorehom_histav)]
BA_means = [np.mean(BA_score_histav), np.mean(BA_scorehom_histav)]
kNN3_means = [np.mean(kNN3_score), np.mean(kNN3_scorehom)]
kNN6_means = [np.mean(kNN6_score), np.mean(kNN6_scorehom)]
JS_std = [np.std(JS_score_histav), np.std(JS_scorehom_histav)]
BA_std = [np.std(BA_score_histav), np.std(BA_scorehom_histav)]
kNN3_std = [np.std(kNN3_score), np.std(kNN3_scorehom)]
kNN6_std = [np.std(kNN6_score), np.std(kNN6_scorehom)]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - 3/2*width, JS_means, width, yerr = JS_std, label='Jensen-Shannon')
rects2 = ax.bar(x - width/2, BA_means, width, yerr = BA_std, label='Bhattacharyya')
rects3 = ax.bar(x + width/2, kNN3_means, width, yerr = kNN3_std, label='3-NN')
rects4 = ax.bar(x + 3/2*width, kNN6_means, width, yerr = kNN6_std, label='6-NN')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Classification performances on Poker DVS dataset')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
