# %%
# %cd '../HOTS'
from Tools import runjit, netparam, histoscore
import numpy as np
# Out:
# /home/antoine/homhots/HOTS/HOTS

# %%
name = 'homhots'
sigma = None
pooling = False
homeinv = False
jitonic = [None,None] #[temporal, spatial]
jitter = False
tau = 5
nblay = 3
nbclust = 4
filt = 2
timestr = '2021-03-18' # this date for 100 digits in learning
record_path = '../Records/EXP_03_NMNIST/'

# %%
nb_test = 10000
nb_train = 60000
ds = 12

nb_test = nb_test//ds
nb_train = nb_train//ds
print(f'training set size: {nb_train} - testing set: {nb_test}')

jit_s = np.arange(0,6,0.4)
jit_t = np.arange(0,300,20)
jit_s, jit_t = jit_s**2, jit_t**2

jitonic= [None,None]
for nblay in [3, 2]:
    for nbclust in [8,16]:
        for name in ['homhots', 'hots']:
            hotshom, homeotest = netparam(name, filt, tau, nblay, nbclust, sigma, homeinv, jitter, timestr)
            trainhistomap = hotshom.running(homeotest=homeotest, nb_digit = nb_train, outstyle='histo')
            testhistomap = hotshom.running(homeotest = homeotest, train=False, nb_digit=nb_test, jitonic=jitonic)
            JS_score = histoscore(trainhistomap,testhistomap, verbose = True)
# Out:
# training set size: 50 - testing set: 8
# 2021-03-18_lagorce_rdn_None_True_[0.25, 1]_[8, 16, 32]_[5000.0, 50000.0, 500000.0]_[2, 4, 8]_False
# ../Records/EXP_03_NMNIST/train/2021-03-18_lagorce_rdn_None_True_[0.25, 1]_[8, 16, 32]_[5000.0, 50000.0, 500000.0]_[2, 4, 8]_False_50_[None, None]_histo.pkl
# ../Records/EXP_03_NMNIST/test/2021-03-18_lagorce_rdn_None_True_[0.25, 1]_[8, 16, 32]_[5000.0, 50000.0, 500000.0]_[2, 4, 8]_False_8_[None, None]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 50.0% - eucli = 50.0% - norm = 62.0%
# Classification scores with entropy: Kullback-Leibler = 50.0% - Jensen-Shannon = 50.0%
# ----------------------------------------------------------------------------------------------------
# 2021-03-18_lagorce_first_None_False_[0.25, 1]_[8, 16, 32]_[5000.0, 50000.0, 500000.0]_[2, 4, 8]_True
# ../Records/EXP_03_NMNIST/train/2021-03-18_lagorce_first_None_False_[0.25, 1]_[8, 16, 32]_[5000.0, 50000.0, 500000.0]_[2, 4, 8]_True_50_[None, None]_histo.pkl
# no jitter
#   4%|▍         | 2/50 [00:03<01:16,  1.60s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5377e9f50928> in <module>
#      16         for name in ['homhots', 'hots']:
#      17             hotshom, homeotest = netparam(name, filt, tau, nblay, nbclust, sigma, homeinv, jitter, timestr)
# ---> 18             trainhistomap = hotshom.running(homeotest=homeotest, nb_digit = nb_train, outstyle='histo')
#      19             testhistomap = hotshom.running(homeotest = homeotest, train=False, nb_digit=nb_test, jitonic=jitonic)
#      20             JS_score = histoscore(trainhistomap,testhistomap, verbose = True)
#
# ~/homhots/HOTS/HOTS/Network.py in running(self, homeotest, train, outstyle, nb_digit, jitonic, dataset, to_record)
#     261                 events, target = next(iter(loader))
#     262                 for iev in range(events.shape[1]):
# --> 263                     out, activout = self.run(events[0][iev][x_index].item(), \
#     264                                             events[0][iev][y_index].item(), \
#     265                                             events[0][iev][t_index].item(), \
#
# ~/homhots/HOTS/HOTS/Network.py in run(self, x, y, t, p, learn, to_record)
#     304             timesurf, activ = self.TS[lay].addevent(x, y, t, p)
#     305             if activ:
# --> 306                 p, dist = self.L[lay].run(timesurf, learn)
#     307                 if to_record:
#     308                     self.stats[lay].update(p, self.L[lay].kernel, timesurf, dist)
#
# ~/homhots/HOTS/HOTS/Layer.py in run(self, TS, learn)
#      59         plotdic = False
#      60         if self.algo=='lagorce':
# ---> 61             h, temphisto, dist = self.lagorce(TS, learn)
#      62         elif self.algo=='mpursuit':
#      63             h, temphisto, dist = self.mpursuit(TS, learn)
#
# ~/homhots/HOTS/HOTS/Layer.py in lagorce(self, TS, learn)
#      96                 return h, temphisto, 0
#      97
# ---> 98         Distance_to_proto = np.linalg.norm(TS - self.kernel, ord=2, axis=0)
#      99
#     100         gain = np.ones([len(self.cumhisto)])
#
# <__array_function__ internals> in norm(*args, **kwargs)
#
# /usr/lib/python3/dist-packages/numpy/linalg/linalg.py in norm(x, ord, axis, keepdims)
#    2510         elif ord is None or ord == 2:
#    2511             # special case for speedup
# -> 2512             s = (x.conj() * x).real
#    2513             return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2514         else:
#
# KeyboardInterrupt:
