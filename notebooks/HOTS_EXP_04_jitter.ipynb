# %% [markdown]
# # HOTS_EXP_04_jitter
#
# Makes performance test with different jitter values

# %%
# %cd '../HOTS'
from Tools import runjit
import numpy as np
# Out:
# /Users/joe/Documents/boulot/git/homhots/HOTS/HOTS

# %% [markdown]
# ## Network parameters

# %%
name = 'homhots'
sigma = None
pooling = False
homeinv = False
jitonic = [None,None] #[temporal, spatial]
jitter = False
tau = 5
nblay = 3
nbclust = 4
filt = 2
timestr = '2021-02-16'
record_path = '../Records/EXP_03_NMNIST/'

# %% [markdown]
# ## Run for jitter values and number of digits defined below

# %%
nb_test = 10000
nb_train = 60000
ds = 1200


nb_test = nb_test//ds
nb_train = nb_train//ds
print(f'training set size: {nb_train} - testing set: {nb_test}')

jit_s = np.zeros(1)#np.arange(0,6,0.2)
jit_t = np.zeros(1)#np.arange(0,300,10)
jit_s, jit_t = jit_s**2, jit_t**2

import cProfile

cProfile.run('runjit(timestr, name, record_path, filt, tau, nblay, nbclust, sigma, homeinv, jitter, jit_s, jit_t, nb_train, nb_test, verbose=True)')


#score_T, jit_t, score_S, jit_s = runjit(timestr, name, record_path, filt, tau, nblay, nbclust, sigma, homeinv, jitter, jit_s, jit_t, nb_train, nb_test, verbose=True)
# Out:
# training set size: 50 - testing set: 8
# ../Records/EXP_03_NMNIST/train/2021-02-16_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[5000.0, 50000.0, 500000.0]_[2, 4, 8]_False_50_[None, None]_histo.pkl
# ../Records/EXP_03_NMNIST/test/2021-02-16_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[5000.0, 50000.0, 500000.0]_[2, 4, 8]_False_8_[None, 0.0]_histo.pkl
# -----------------------------------------------SCORES-----------------------------------------------
# Classification scores with HOTS measures: bhatta = 37.5% - eucli = 37.5% - norm = 12.5%
# Classification scores with entropy: Kullback-Leibler = 37.5% - Jensen-Shannon = 37.5%
# ----------------------------------------------------------------------------------------------------
# ../Records/EXP_03_NMNIST/test/2021-02-16_lagorce_rdn_None_True_[0.25, 1]_[4, 8, 16]_[5000.0, 50000.0, 500000.0]_[2, 4, 8]_False_8_[0.0, None]_histo.pkl
# time jitter -> var = 0.0
# 100%|██████████| 8/8 [00:31<00:00,  3.91s/it]
# ...
